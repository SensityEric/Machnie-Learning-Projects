# %%
import numpy as np
import pandas as pd

# %%
police_data =pd.read_csv(r'C:\Users\Admin\Downloads\police.csv')
police_data
# Out:
#       state   stop_date stop_time  county_name driver_gender driver_race  \
# 0        RI  2005-01-04     12:55          NaN             M       White
# 1        RI  2005-01-23     23:15          NaN             M       White
# 2        RI  2005-02-17     04:15          NaN             M       White
# 3        RI  2005-02-20     17:15          NaN             M       White
# 4        RI  2005-02-24     01:20          NaN             F       White
# ...     ...         ...       ...          ...           ...         ...
# 91736    RI  2015-12-31     21:21          NaN             F       Black
# 91737    RI  2015-12-31     21:59          NaN             F       White
# 91738    RI  2015-12-31     22:04          NaN             M       White
# 91739    RI  2015-12-31     22:09          NaN             F    Hispanic
# 91740    RI  2015-12-31     22:47          NaN             M       White
#
#                         violation_raw            violation  search_conducted  \
# ...

# %%
Speeding = police_data[police_data.violation =='Speeding'] # Total violation during according to Speeding
Speeding.head(60)
# Out:
#    state   stop_date stop_time  county_name driver_gender driver_race  \
# 1     RI  2005-01-23     23:15          NaN             M       White
# 2     RI  2005-02-17     04:15          NaN             M       White
# 4     RI  2005-02-24     01:20          NaN             F       White
# 5     RI  2005-03-14     10:00          NaN             F       White
# 6     RI  2005-03-29     21:55          NaN             M       White
# 7     RI  2005-04-04     21:25          NaN             M       White
# 8     RI  2005-07-14     11:20          NaN             F       White
# 9     RI  2005-07-14     19:55          NaN             M       White
# 10    RI  2005-07-18     19:10          NaN             M       White
# 11    RI  2005-07-18     19:30          NaN             F       White
# 12    RI  2005-07-19     00:30          NaN             M       White
# 13    RI  2005-07-24     20:10          NaN             F       White
# ...

# %% [markdown]
# ##  a. what percentage of female had a violation of speeding?

# %%
Total_Speeding = Speeding.driver_gender.value_counts(normalize=True)*100
Total_Speeding.loc['F']
# Out:
# 32.311091836523964

# %% [markdown]
# ##  b. How many of the arrested drivers were male and what was their race?

# %%
male = police_data[['driver_gender','is_arrested','driver_race']]
male_only = male[(male['driver_gender']=='M')]
male_only[(male_only['is_arrested']== True)]
# Out:
#       driver_gender is_arrested driver_race
# 3                 M        True       White
# 16                M        True       White
# 61                M        True       White
# 71                M        True       White
# 82                M        True       White
# ...             ...         ...         ...
# 91417             M        True    Hispanic
# 91453             M        True    Hispanic
# 91510             M        True       Black
# 91527             M        True       White
# 91574             M        True       White
#
# [2409 rows x 3 columns]

# %% [markdown]
# ##  In different tables, show the various stop outcomes and their respective violations

# %%
violation_stop = police_data[['violation','stop_outcome']]
violation_stop
# Out:
#                  violation   stop_outcome
# 0                Equipment       Citation
# 1                 Speeding       Citation
# 2                 Speeding       Citation
# 3                    Other  Arrest Driver
# 4                 Speeding       Citation
# ...                    ...            ...
# 91736     Moving violation       Citation
# 91737             Speeding       Citation
# 91738     Moving violation       Citation
# 91739            Equipment        Warning
# 91740  Registration/plates       Citation
#
# [91741 rows x 2 columns]

# %% [markdown]
# ##  d.i. What percentage of drivers who were stopped were black, how many were drug related, did it lead to an arrest? If it led to an arrest, how many?

# %%
group_a = police_data[['driver_race','is_arrested','drugs_related_stop']]
group_b =group_a[(group_a['driver_race']=='Black') & (group_a['is_arrested']==True) & (group_a['drugs_related_stop']==True)]
group_b.describe()
# Out:
#        driver_race is_arrested drugs_related_stop
# count           63          63                 63
# unique           1           1                  1
# top          Black        True               True
# freq            63          63                 63

# %% [markdown]
# ## d ii. What percentage of drivers who were stopped were white, how many were drug related, did it lead to an arrest? If it led to an arrest, how many?

# %%
group_c =group_a[(group_a['driver_race']=='White') & (group_a['is_arrested']==True) & (group_a['drugs_related_stop']==True)]
group_c.value_counts(normalize=True)*100
# Out:
# driver_race  is_arrested  drugs_related_stop
# White        True         True                  100.0
# dtype: float64

# %% [markdown]
# ## 2.From the instagram_global_top_1000 dataset, answer the following questions

# %%
instagram = pd.read_csv(r'C:\Users\Admin\Downloads\instagram_global_top_1000.csv')
instagram.head()
# Out:
#   Country  Rank        Account              Title  \
# 0     All     1      cristiano  Cristiano Ronaldo
# 1     All     2    kyliejenner            Kylie 🤍
# 2     All     3       leomessi          Leo Messi
# 3     All     4  kendalljenner            Kendall
# 4     All     5    selenagomez       Selena Gomez
#
#                                        Link                   Category  \
# 0      https://www.instagram.com/cristiano/         Sports with a ball
# 1    https://www.instagram.com/kyliejenner/    Fashion|Modeling|Beauty
# 2       https://www.instagram.com/leomessi/  Sports with a ball|Family
# 3  https://www.instagram.com/kendalljenner/           Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/            Music|Lifestyle
#
#      Followers Audience Country  Authentic engagement  Engagement avg  \
# 0  400100000.0            India             7800000.0       9500000.0
# 1  308800000.0    United States             6200000.0      10100000.0
# ...

# %% [markdown]
# ## a. How many influencers in the top 20 are into sports?

# %%
sport = instagram[instagram.Category == 'Sports with a ball']
sport.head(20)
# Out:
#     Country  Rank               Account                  Title  \
# 0       All     1             cristiano      Cristiano Ronaldo
# 10      All    11              neymarjr                  NJ 🇧🇷
# 14      All    15           virat.kohli            Virat Kohli
# 38      All    39             kingjames                      👑
# 40      All    41              k.mbappe         Kylian Mbappé
# 53      All    54           fcbarcelona           FC Barcelona
# 60      All    61               mosalah          Mohamed Salah
# 79      All    80             paulpogba      Paul Labile Pogba
# 83      All    84            realmadrid       Real Madrid C.F.
# 101     All   102           paulodybala           Paulo Dybala
# 107     All   108  iamzlatanibrahimovic     Zlatan Ibrahimović
# 108     All   109          karimbenzema          Karim Benzema
# 116     All   117           sergioramos           Sergio Ramos
# 127     All   128       championsleague  UEFA Champions League
# ...

# %% [markdown]
# ## How many musicians were in the top 100, which countries were their audience from and how many followers did they have?

# %%
music = instagram[instagram.Category =='Music']
music.query( 'Rank< 100')
# Out:
#    Country  Rank            Account          Title  \
# 8      All     9       arianagrande  Ariana Grande
# 9      All    10       billieeilish  BILLIE EILISH
# 11     All    12       lalalalisa_m           LISA
# 12     All    13     jennierubyjane              J
# 19     All    20       justinbieber  Justin Bieber
# 21     All    22    roses_are_rosie          ROSÉ
# 23     All    24         nickiminaj         Barbie
# 29     All    30               zayn     Zayn Malik
# 30     All    31      champagnepapi  champagnepapi
# 34     All    35         badbunnypr            NaN
# 36     All    37              adele          Adele
# 41     All    42             karolg        KAROL G
# 46     All    47            dualipa       DUA LIPA
# 49     All    50         mileycyrus    Miley Cyrus
# 55     All    56        shawnmendes   Shawn Mendes
# 62     All    63           lelepons      Lele Pons
# 67     All    68           ddlovato    Demi Lovato
# ...

# %% [markdown]
# ## c. Find out how many influencers had Indian audiences, their profession, their number of followers and their average engagement.

# %%
all_influencer = instagram[['Title','Audience Country','Category','Followers','Engagement avg']]
indian_audiences =all_influencer[(all_influencer['Audience Country'] == 'India')]
indian_audiences
# Out:
#                               Title Audience Country  \
# 0                 Cristiano Ronaldo            India
# 14                      Virat Kohli            India
# 19                    Justin Bieber            India
# 27                          therock            India
# 28                        Instagram            India
# ..                              ...              ...
# 949        Divyanka Tripathi Dahiya            India
# 973             Ravindrasinh jadeja            India
# 986                    Rishabh Pant            India
# 997  India’s Youth & Fitness IC⭕️N®            India
# 998                    Shakti Mohan            India
#
#                                 Category    Followers  Engagement avg
# 0                     Sports with a ball  400100000.0       9500000.0
# 14                    Sports with a ball  182600000.0       2400000.0
# 19                                 Music  219800000.0       1800000.0
# ...

# %%
indian_audiences.Title.count()
# Out:
# 142

# %% [markdown]
# ## d. What percentage of influencers with average engagement less than 1.5 million were into Beauty and Lifestyle?

# %%
avg_beuaty =instagram[(instagram["Engagement avg"] < 1500000.0) & (instagram["Category"] == "Beauty|Lifestyle")] 
avg_beuaty
# Out:
#     Country  Rank Account           Title                              Link  \
# 344     All   345   avani           avani  https://www.instagram.com/avani/
# 814     All   815    vivi  Vivi Wanderley   https://www.instagram.com/vivi/
#
#              Category   Followers Audience Country  Authentic engagement  \
# 344  Beauty|Lifestyle  18600000.0    United States              396600.0
# 814  Beauty|Lifestyle  12700000.0           Brazil              147300.0
#
#      Engagement avg                     Scraped
# 344        533300.0  2022-02-07 16:50:24.798803
# 814        242000.0  2022-02-07 16:50:24.798803

# %% [markdown]
# ## e. What percentage of the influencers were into Sports with a ball, find out the difference between their average engagements and authentic engagements?

# %%
sport_1 =instagram[instagram.Category == 'Sports with a ball']
sport_1
# Out:
#     Country  Rank           Account              Title  \
# 0       All     1         cristiano  Cristiano Ronaldo
# 10      All    11          neymarjr              NJ 🇧🇷
# 14      All    15       virat.kohli        Virat Kohli
# 38      All    39         kingjames                  👑
# 40      All    41          k.mbappe     Kylian Mbappé
# ..      ...   ...               ...                ...
# 969     All   970  jordialbaoficial         Jordi Alba
# 972     All   973       davidluiz23         David Luiz
# 983     All   984          casemiro           Casemiro
# 986     All   987        rishabpant       Rishabh Pant
# 996     All   997       manuelneuer       Manuel Neuer
#
#                                             Link            Category  \
# 0           https://www.instagram.com/cristiano/  Sports with a ball
# 10           https://www.instagram.com/neymarjr/  Sports with a ball
# 14        https://www.instagram.com/virat.kohli/  Sports with a ball
# ...

# %%
sport_2 =sport_1[['Engagement avg','Authentic engagement']].sum()
differ = sport_2.iloc[0] -sport_2.iloc[1]
differ
# Out:
# 20070100.0
